# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Call LLM Using Groq Models

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(model="qwen/qwen3-32b", reasoning_format="parsed")

messages = [
    (
        "system",
        "You are a helpful assistant that gives a short answer to a question",
    ),
    (
        "human", 
        "How many moons does Jupiter have?"
    ),
]
ai_msg = llm.invoke(messages)
print(ai_msg.content)
# Out:
# As of the latest confirmed count, Jupiter has **95 moons**. This number continues to grow as new discoveries are made and officially recognized by the International Astronomical Union (IAU).

# %% [markdown]
# ## Call LLM Using Google LLM API

# %%
llm = ChatGoogleGenerativeAI(model="gemma-4-31b-it")

response = llm.invoke("What is the agentic AI framework?")
print(response.text)
# Out:
# An **Agentic AI Framework** is a structural design pattern and a set of tools used to build **AI Agents**.
#
# To understand this, you first have to understand the difference between a standard LLM (like a basic chatbot) and an AI Agent:
# *   **Standard LLM (Reactive):** You give it a prompt; it gives you a response. It is a "text-in, text-out" machine.
# *   **AI Agent (Proactive):** You give it a **goal** (e.g., "Research this company and write a competitive analysis report"). The agent then decides which steps to take, which tools to use, and corrects its own mistakes until the goal is achieved.
#
# An **Agentic Framework** provides the "scaffolding" that allows an LLM to move from simply talking to actually **doing**.
#
# ---
#
# ### The Core Components of an Agentic Framework
# Most agentic frameworks are built around four primary pillars:
#
# #### 1. The Brain (The LLM)
# The Large Language Model acts as the reasoning engine. It doesn't just generate text; it handles **planning** and **decision-making**. It decides: *"To answer this question, I first need to search the web, then read three articles, then synthesize the data."*
#
# #### 2. Planning (Reasoning Loops)
# Frameworks implement specific reasoning patterns so the AI doesn't just guess. Common patterns include:
# *   **Chain-of-Thought (CoT):** Breaking a complex problem into smaller, logical steps.
# *   **ReAct (Reason + Act):** A loop where the agent thinks, takes an action, observes the result, and then thinks again based on that result.
# *   **Reflection/Self-Criticism:** The agent reviews its own work and corrects errors before presenting the final answer.
#
# #### 3. Memory
# Since LLMs have a limited "context window," frameworks provide memory systems:
# *   **Short-term Memory:** Keeping track of the current conversation and immediate steps.
# *   **Long-term Memory:** Using **Vector Databases** (like Pinecone or Milvus) to store and retrieve documents or past experiences via RAG (Retrieval-Augmented Generation).
#
# #### 4. Tool Use (The "Hands")
# This is what makes an agent "agentic." The framework allows the LLM to call external functions or APIs. Examples include:
# *   **Web Search:** Using Google or Tavily to get real-time data.
# *   **Code Execution:** Writing and running Python code to solve a math problem or create a chart.
# *   **App Integration:** Sending an email via Gmail or updating a row in Salesforce.
#
# ---
#
# ### How the Agentic Loop Works
# Instead of a straight line (Prompt $\rightarrow$ Response), an agentic framework operates in a **loop**:
#
# 1.  **Goal:** User says, "Find the best-priced flight to Tokyo and add it to my calendar."
# 2.  **Plan:** Agent decides: *1. Search flights $\rightarrow$ 2. Compare prices $\rightarrow$ 3. Access Calendar API $\rightarrow$ 4. Book/Add event.*
# 3.  **Action:** Agent calls a flight search API.
# 4.  **Observation:** Agent sees the results (e.g., "Flight A is \$800, Flight B is \$700").
# 5.  **Reasoning:** "Flight B is cheaper; I will proceed with that one."
# 6.  **Execution:** Agent calls the Calendar API to add the event.
# 7.  **Final Output:** "I've found the best flight for \$700 and added it to your calendar."
#
# ---
#
# ### Popular Agentic AI Frameworks
# If you are looking to build or use these, these are the current industry leaders:
#
# *   **LangChain / LangGraph:** The most popular ecosystem. LangGraph specifically allows for "cyclic" graphs, which are essential for agents that need to loop back and correct themselves.
# *   **CrewAI:** Focuses on **Multi-Agent Orchestration**. You can create a "Crew" where one agent is a "Researcher," another is a "Writer," and another is a "Manager" who oversees the others.
# *   **Microsoft AutoGen:** A framework that allows multiple agents to talk to each other to solve a task autonomously.
# *   **OpenAI Assistants API:** A built-in framework by OpenAI that handles memory (threads) and tool use (code interpreter, retrieval) automatically.
#
# ### Summary Table: Chatbot vs. Agentic Framework
#
# | Feature | Standard Chatbot | Agentic Framework |
# | :--- | :--- | :--- |
# | **Interaction** | Prompt $\rightarrow$ Response | Goal $\rightarrow$ Iterative Process |
# | **Autonomy** | Low (follows instructions) | High (determines its own steps) |
# | **Tools** | Limited/None | Can use APIs, Web, Databases |
# | **Error Handling** | Hallucinates or fails | Reflects and corrects itself |
# | **Workflow** | Linear | Cyclic/Looping |

# %%
llm = ChatGoogleGenerativeAI(model="gemma-4-31b-it")

response = llm.invoke([
    ["system", "You are a helpful assistant that answers in short one line"],
    ["human", "How many moons does Jupiter have?"]
])
print(response.text)
# Out:
# Jupiter has 95 moons.

# %% [markdown]
# ## Temperature

# %%
prompt = "Write a single tagline for a agentic AI framework. Only output the tagline, nothing else."

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0)

response = llm.invoke(prompt)
print(response.text)
# Out:
# Build AI with Agency.

# %%
prompt = "Write a single tagline for a quirky coffee shop. Only output the tagline, nothing else."

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=1)

response = llm.invoke(prompt)
print(response.text)
# Out:
# Uncommon grounds for uncommon people.
