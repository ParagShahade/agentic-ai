# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Call LLM Using Groq Models

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(model="qwen/qwen3-32b", reasoning_format="parsed")

messages = [
    (
        "system",
        "You are a helpful assistant that gives a short answer to a question",
    ),
    ("human", "How many moons does Jupiter have?"),
]
ai_msg = llm.invoke(messages)
print(ai_msg.content)
# Out:
# As of 2023, Jupiter has **95 confirmed moons**, making it the planet with the most moons in the solar system. This number includes its four large Galilean moons (Io, Europa, Ganymede, and Callisto) and many smaller, irregularly orbiting moons. The count may increase as new discoveries are made.

# %% [markdown]
# ## Call LLM Using Google LLM API

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemma-4-31b-it")

response = llm.invoke("What is the agentic AI framework?")
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File /workspaces/agentic-ai/.venv/lib/python3.14/site-packages/langchain_google_genai/chat_models.py:3166, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3165 try:
# -> 3166     response: GenerateContentResponse = self.client.models.generate_content(
#    3167         **request,
#    3168     )
#    3169 except ClientError as e:
#
# File /workspaces/agentic-ai/.venv/lib/python3.14/site-packages/google/genai/models.py:6331, in Models.generate_content(self, model, contents, config)
#    6330 i += 1
# -> 6331 response = self._generate_content(
#    6332     model=model, contents=contents, config=parsed_config
#    6333 )
#    6335 function_map = _extra_utils.get_function_map(parsed_config)
#
# ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemma-4-31b-it")

response = llm.invoke(
    [
        ["system", "You are a helpful assistant that answers in short one line"],
        ["human", "How many moons does Jupiter have?"],
    ]
)
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File /workspaces/agentic-ai/.venv/lib/python3.14/site-packages/langchain_google_genai/chat_models.py:3166, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3165 try:
# -> 3166     response: GenerateContentResponse = self.client.models.generate_content(
#    3167         **request,
#    3168     )
#    3169 except ClientError as e:
#
# File /workspaces/agentic-ai/.venv/lib/python3.14/site-packages/google/genai/models.py:6331, in Models.generate_content(self, model, contents, config)
#    6330 i += 1
# -> 6331 response = self._generate_content(
#    6332     model=model, contents=contents, config=parsed_config
#    6333 )
#    6335 function_map = _extra_utils.get_function_map(parsed_config)
#
# ...

# %% [markdown]
# ## Temperature

# %%
prompt = "Write a single tagline for a agentic AI framework. Only output the tagline, nothing else."

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0)

response = llm.invoke(prompt)
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File /workspaces/agentic-ai/.venv/lib/python3.14/site-packages/langchain_google_genai/chat_models.py:3166, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3165 try:
# -> 3166     response: GenerateContentResponse = self.client.models.generate_content(
#    3167         **request,
#    3168     )
#    3169 except ClientError as e:
#
# File /workspaces/agentic-ai/.venv/lib/python3.14/site-packages/google/genai/models.py:6331, in Models.generate_content(self, model, contents, config)
#    6330 i += 1
# -> 6331 response = self._generate_content(
#    6332     model=model, contents=contents, config=parsed_config
#    6333 )
#    6335 function_map = _extra_utils.get_function_map(parsed_config)
#
# ...

# %%
prompt = "Write a single tagline for a quirky coffee shop. Only output the tagline, nothing else."

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=1)

response = llm.invoke(prompt)
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File /workspaces/agentic-ai/.venv/lib/python3.14/site-packages/langchain_google_genai/chat_models.py:3166, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3165 try:
# -> 3166     response: GenerateContentResponse = self.client.models.generate_content(
#    3167         **request,
#    3168     )
#    3169 except ClientError as e:
#
# File /workspaces/agentic-ai/.venv/lib/python3.14/site-packages/google/genai/models.py:6331, in Models.generate_content(self, model, contents, config)
#    6330 i += 1
# -> 6331 response = self._generate_content(
#    6332     model=model, contents=contents, config=parsed_config
#    6333 )
#    6335 function_map = _extra_utils.get_function_map(parsed_config)
#
# ...
